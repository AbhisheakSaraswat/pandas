# %%
import pandas as pd

# %%
# read the data
df = pd.read_csv("SalesData.csv")

# %%
df.shape
# Out:
# (53, 6)

# %%
df.head()
# Out:
#          Order ID    Customer Name      Segment         City     Sales  \
# 0  CA-2014-167164  Alejandro Grove     Consumer  West Jordan    55.500
# 1  CA-2015-106320      Emily Burns     Consumer         Orem  1044.630
# 2  CA-2015-128167     Ken Lonsdale     Consumer       Layton     4.960
# 3  CA-2014-104472            Lucas  Home Office         Orem    59.808
# 4  CA-2014-104472            Lucas  Home Office         Orem    73.320
#
#      Profit
# 0    9.9900
# 1  240.2649
# 2    2.3312
# 3   19.4376
# 4   21.9960

# %%
# iloc

# %%
df.iloc[3]
# Out:
# Order ID         CA-2014-104472
# Customer Name             Lucas
# Segment             Home Office
# City                       Orem
# Sales                    59.808
# Profit                  19.4376
# Name: 3, dtype: object

# %%
df.iloc[[2,3]]
# Out:
#          Order ID Customer Name      Segment    City   Sales   Profit
# 2  CA-2015-128167  Ken Lonsdale     Consumer  Layton   4.960   2.3312
# 3  CA-2014-104472         Lucas  Home Office    Orem  59.808  19.4376

# %%
df2 = df.set_index("Customer Name")
df2.head(2)
# Out:
#                        Order ID   Segment         City    Sales    Profit
# Customer Name
# Alejandro Grove  CA-2014-167164  Consumer  West Jordan    55.50    9.9900
# Emily Burns      CA-2015-106320  Consumer         Orem  1044.63  240.2649

# %%
df2.iloc['Emily Burns']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-029890606b8e> in <module>
# ----> 1 df2.iloc['Emily Burns']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
#    1500             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
df2.iloc[2]
# Out:
# Order ID    CA-2015-128167
# Segment           Consumer
# City                Layton
# Sales                 4.96
# Profit              2.3312
# Name: Ken Lonsdale, dtype: object

# %%
df.head()
# Out:
#          Order ID    Customer Name      Segment         City     Sales  \
# 0  CA-2014-167164  Alejandro Grove     Consumer  West Jordan    55.500
# 1  CA-2015-106320      Emily Burns     Consumer         Orem  1044.630
# 2  CA-2015-128167     Ken Lonsdale     Consumer       Layton     4.960
# 3  CA-2014-104472            Lucas  Home Office         Orem    59.808
# 4  CA-2014-104472            Lucas  Home Office         Orem    73.320
#
#      Profit
# 0    9.9900
# 1  240.2649
# 2    2.3312
# 3   19.4376
# 4   21.9960

# %%
df.iloc[2,3]
# Out:
# 'Layton'

# %%
df.iloc[[2,3],:]
# Out:
#          Order ID Customer Name      Segment    City   Sales   Profit
# 2  CA-2015-128167  Ken Lonsdale     Consumer  Layton   4.960   2.3312
# 3  CA-2014-104472         Lucas  Home Office    Orem  59.808  19.4376

# %%
df.iloc[[2,5,7,9,15,30]]
# Out:
#           Order ID      Customer Name      Segment            City   Sales  \
# 2   CA-2015-128167       Ken Lonsdale     Consumer          Layton    4.96
# 5   CA-2015-120362              Lucas     Consumer           Provo  912.75
# 7   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove  447.84
# 9   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove  399.96
# 15  CA-2016-125738    Patrick Bzostek  Home Office  Salt Lake City   71.60
# 30  CA-2015-123568       Sanjit Chand     Consumer     West Jordan   66.69
#
#       Profit
# 2     2.3312
# 5   118.6575
# 7   219.4416
# 9    34.9965
# 15   32.9360
# 30   22.0077

# %%
df.iloc[:,[1,3,5]]
# Out:
#          Customer Name            City    Profit
# 0      Alejandro Grove     West Jordan    9.9900
# 1          Emily Burns            Orem  240.2649
# 2         Ken Lonsdale          Layton    2.3312
# 3                Lucas            Orem   19.4376
# 4                Lucas            Orem   21.9960
# 5                Lucas           Provo  118.6575
# 6    Valerie Dominguez  Pleasant Grove  305.1300
# 7    Valerie Dominguez  Pleasant Grove  219.4416
# 8    Valerie Dominguez  Pleasant Grove    4.2640
# 9    Valerie Dominguez  Pleasant Grove   34.9965
# 10   Valerie Dominguez  Pleasant Grove    7.9450
# 11   Valerie Dominguez  Pleasant Grove    4.7792
# 12     Patrick Bzostek  Salt Lake City   21.0128
# 13     Patrick Bzostek  Salt Lake City   28.8576
# 14     Patrick Bzostek  Salt Lake City   13.0375
# 15     Patrick Bzostek  Salt Lake City   32.9360
# 16      Rick Huthwaite           Provo   12.4320
# 17      Tamara Manning            Orem  140.6860
# ...

# %%
df.iloc[[2,4,5],2:5]
# Out:
#        Segment    City   Sales
# 2     Consumer  Layton    4.96
# 4  Home Office    Orem   73.32
# 5     Consumer   Provo  912.75

# %%
df.columns
# Out:
# Index(['Order ID', 'Customer Name', 'Segment', 'City', 'Sales', 'Profit'], dtype='object')

# %%
df.iloc[[1,4,5,8,10],1:5]
# Out:
#         Customer Name      Segment            City    Sales
# 1         Emily Burns     Consumer            Orem  1044.63
# 4               Lucas  Home Office            Orem    73.32
# 5               Lucas     Consumer           Provo   912.75
# 8   Valerie Dominguez     Consumer  Pleasant Grove    16.40
# 10  Valerie Dominguez     Consumer  Pleasant Grove   158.90

# %%
# loc
df.loc[5]
# Out:
# Order ID         CA-2015-120362
# Customer Name             Lucas
# Segment                Consumer
# City                      Provo
# Sales                    912.75
# Profit                 118.6575
# Name: 5, dtype: object

# %%
df.loc[[2,4,6,8,10]]
# Out:
#           Order ID      Customer Name      Segment            City    Sales  \
# 2   CA-2015-128167       Ken Lonsdale     Consumer          Layton     4.96
# 4   CA-2014-104472              Lucas  Home Office            Orem    73.32
# 6   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove  1089.75
# 8   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove    16.40
# 10  CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove   158.90
#
#       Profit
# 2     2.3312
# 4    21.9960
# 6   305.1300
# 8     4.2640
# 10    7.9450

# %%
df.loc[[2,4,5,6,7],["Segment","Profit"]]
# Out:
#        Segment    Profit
# 2     Consumer    2.3312
# 4  Home Office   21.9960
# 5     Consumer  118.6575
# 6     Consumer  305.1300
# 7     Consumer  219.4416

# %%
df.loc[[2,4,5,6,7],[2,5]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-9cfe24d3407a> in <module>
# ----> 1 df.loc[[2,4,5,6,7],[2,5]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1065         # ugly hack for GH #836
#    1066         if self._multi_take_opportunity(tup):
# -> 1067             return self._multi_take(tup)
#    1068
#    1069         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.loc[df['City'] == "West Jordan",:]
# Out:
#           Order ID    Customer Name   Segment         City  Sales   Profit
# 0   CA-2014-167164  Alejandro Grove  Consumer  West Jordan  55.50   9.9900
# 28  CA-2015-123568     Sanjit Chand  Consumer  West Jordan   5.04   0.2016
# 29  CA-2015-123568     Sanjit Chand  Consumer  West Jordan  92.94  41.8230
# 30  CA-2015-123568     Sanjit Chand  Consumer  West Jordan  66.69  22.0077
# 31  CA-2015-123568     Sanjit Chand  Consumer  West Jordan  91.68  28.6500

# %%
df.loc[df.City == 'West Jordan',"Segment":"Profit"]
# Out:
#      Segment         City  Sales   Profit
# 0   Consumer  West Jordan  55.50   9.9900
# 28  Consumer  West Jordan   5.04   0.2016
# 29  Consumer  West Jordan  92.94  41.8230
# 30  Consumer  West Jordan  66.69  22.0077
# 31  Consumer  West Jordan  91.68  28.6500

# %%
df.loc[df.City == 'West Jordan',["Segment","Profit"]]
# Out:
#      Segment   Profit
# 0   Consumer   9.9900
# 28  Consumer   0.2016
# 29  Consumer  41.8230
# 30  Consumer  22.0077
# 31  Consumer  28.6500

# %%
df.iloc[0:4,:]
# Out:
#          Order ID    Customer Name      Segment         City     Sales  \
# 0  CA-2014-167164  Alejandro Grove     Consumer  West Jordan    55.500
# 1  CA-2015-106320      Emily Burns     Consumer         Orem  1044.630
# 2  CA-2015-128167     Ken Lonsdale     Consumer       Layton     4.960
# 3  CA-2014-104472            Lucas  Home Office         Orem    59.808
#
#      Profit
# 0    9.9900
# 1  240.2649
# 2    2.3312
# 3   19.4376

# %%
df.loc[0:4,:]
# Out:
#          Order ID    Customer Name      Segment         City     Sales  \
# 0  CA-2014-167164  Alejandro Grove     Consumer  West Jordan    55.500
# 1  CA-2015-106320      Emily Burns     Consumer         Orem  1044.630
# 2  CA-2015-128167     Ken Lonsdale     Consumer       Layton     4.960
# 3  CA-2014-104472            Lucas  Home Office         Orem    59.808
# 4  CA-2014-104472            Lucas  Home Office         Orem    73.320
#
#      Profit
# 0    9.9900
# 1  240.2649
# 2    2.3312
# 3   19.4376
# 4   21.9960

# %%
df2.head()
# Out:
#                        Order ID      Segment         City     Sales    Profit
# Customer Name
# Alejandro Grove  CA-2014-167164     Consumer  West Jordan    55.500    9.9900
# Emily Burns      CA-2015-106320     Consumer         Orem  1044.630  240.2649
# Ken Lonsdale     CA-2015-128167     Consumer       Layton     4.960    2.3312
# Lucas            CA-2014-104472  Home Office         Orem    59.808   19.4376
# Lucas            CA-2014-104472  Home Office         Orem    73.320   21.9960

# %%
df.iloc[2]
# Out:
# Order ID         CA-2015-128167
# Customer Name      Ken Lonsdale
# Segment                Consumer
# City                     Layton
# Sales                      4.96
# Profit                   2.3312
# Name: 2, dtype: object

# %%
df2.loc["Emily Burns"]
# Out:
# Order ID    CA-2015-106320
# Segment           Consumer
# City                  Orem
# Sales              1044.63
# Profit            240.2649
# Name: Emily Burns, dtype: object

# %%
df2.loc["Emily Burns":"Evon"]
# Out:
#                          Order ID      Segment            City     Sales  \
# Customer Name
# Emily Burns        CA-2015-106320     Consumer            Orem  1044.630
# Ken Lonsdale       CA-2015-128167     Consumer          Layton     4.960
# Lucas              CA-2014-104472  Home Office            Orem    59.808
# Lucas              CA-2014-104472  Home Office            Orem    73.320
# Lucas              CA-2015-120362     Consumer           Provo   912.750
# Valerie Dominguez  CA-2014-126361     Consumer  Pleasant Grove  1089.750
# Valerie Dominguez  CA-2014-126361     Consumer  Pleasant Grove   447.840
# Valerie Dominguez  CA-2014-126361     Consumer  Pleasant Grove    16.400
# Valerie Dominguez  CA-2014-126361     Consumer  Pleasant Grove   399.960
# Valerie Dominguez  CA-2014-126361     Consumer  Pleasant Grove   158.900
# Valerie Dominguez  CA-2014-126361     Consumer  Pleasant Grove    13.184
# Patrick Bzostek    CA-2016-125738  Home Office  Salt Lake City    45.680
# ...

# %%
df['Customer Name'].unique()
# Out:
# array(['Alejandro Grove', 'Emily Burns', 'Ken Lonsdale', 'Lucas',
#        'Valerie Dominguez', 'Patrick Bzostek', 'Rick Huthwaite',
#        'Tamara Manning', 'Evon', 'Dean percer', 'Sanjit Chand',
#        'Sarah Foster', 'Jason Fortune-', 'Karen Seio', 'John Grady',
#        'Justin MacKendrick', 'Joy Bell-', "Jack O'Briant", 'Ken Heidel',
#        'Eugene Moren', 'Stuart Van', 'Dennis Bolton', "Doug O'Connell",
#        'Max Jones', 'Denny Ordway'], dtype=object)

# %%
boolean = df.Profit > 200

# %%
df.head()
# Out:
#          Order ID    Customer Name      Segment         City     Sales  \
# 0  CA-2014-167164  Alejandro Grove     Consumer  West Jordan    55.500
# 1  CA-2015-106320      Emily Burns     Consumer         Orem  1044.630
# 2  CA-2015-128167     Ken Lonsdale     Consumer       Layton     4.960
# 3  CA-2014-104472            Lucas  Home Office         Orem    59.808
# 4  CA-2014-104472            Lucas  Home Office         Orem    73.320
#
#      Profit
# 0    9.9900
# 1  240.2649
# 2    2.3312
# 3   19.4376
# 4   21.9960

# %%
boolean
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46     True
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# Name: Profit, dtype: bool

# %%
df.loc[boolean]
# Out:
#           Order ID      Customer Name      Segment            City    Sales  \
# 1   CA-2015-106320        Emily Burns     Consumer            Orem  1044.63
# 6   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove  1089.75
# 7   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove   447.84
# 46  CA-2016-139997       Eugene Moren  Home Office            Lehi  1499.95
#
#       Profit
# 1   240.2649
# 6   305.1300
# 7   219.4416
# 46  449.9850

# %%
df.iloc[list(df.Profit > 200)]
# Out:
#           Order ID      Customer Name      Segment            City    Sales  \
# 1   CA-2015-106320        Emily Burns     Consumer            Orem  1044.63
# 6   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove  1089.75
# 7   CA-2014-126361  Valerie Dominguez     Consumer  Pleasant Grove   447.84
# 46  CA-2016-139997       Eugene Moren  Home Office            Lehi  1499.95
#
#       Profit
# 1   240.2649
# 6   305.1300
# 7   219.4416
# 46  449.9850
