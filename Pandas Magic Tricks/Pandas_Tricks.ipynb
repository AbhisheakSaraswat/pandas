# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("Superstore.xls")

# %%
df.shape
# Out:
# (9994, 11)

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Customer Name            object
# City                     object
# State                    object
# Region                   object
# Category                 object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.head(2)
# Out:
#          Order ID Order Date Customer Name       City     State Region  \
# 0  CA-2016-152156 2016-11-08   Claire Gute  Henderson  Kentucky  South
# 1  CA-2016-152156 2016-11-08   Claire Gute  Henderson  Kentucky  South
#
#     Category   Sales  Quantity  Discount    Profit
# 0  Furniture  261.96         2       0.0   41.9136
# 1  Furniture  731.94         3       0.0  219.5820

# %% [markdown]
# ### Select_dtypes

# %%
df.select_dtypes(include = ['float64','int64'])
# Out:
#          Sales  Quantity  Discount    Profit
# 0     261.9600         2      0.00   41.9136
# 1     731.9400         3      0.00  219.5820
# 2      14.6200         2      0.00    6.8714
# 3     957.5775         5      0.45 -383.0310
# 4      22.3680         2      0.20    2.5164
# ...        ...       ...       ...       ...
# 9989   25.2480         3      0.20    4.1028
# 9990   91.9600         2      0.00   15.6332
# 9991  258.5760         2      0.20   19.3932
# 9992   29.6000         4      0.00   13.3200
# 9993  243.1600         2      0.00   72.9480
#
# [9994 rows x 4 columns]

# %%
df.select_dtypes(include = "object")
# Out:
#             Order ID     Customer Name             City       State Region  \
# 0     CA-2016-152156       Claire Gute        Henderson    Kentucky  South
# 1     CA-2016-152156       Claire Gute        Henderson    Kentucky  South
# 2     CA-2016-138688   Darrin Van Huff      Los Angeles  California   West
# 3     US-2015-108966    Sean O'Donnell  Fort Lauderdale     Florida  South
# 4     US-2015-108966    Sean O'Donnell  Fort Lauderdale     Florida  South
# ...              ...               ...              ...         ...    ...
# 9989  CA-2014-110422  Tom Boeckenhauer            Miami     Florida  South
# 9990  CA-2017-121258       Dave Brooks       Costa Mesa  California   West
# 9991  CA-2017-121258       Dave Brooks       Costa Mesa  California   West
# 9992  CA-2017-121258       Dave Brooks       Costa Mesa  California   West
# 9993  CA-2017-119914      Chris Cortes      Westminster  California   West
#
#              Category
# 0           Furniture
# 1           Furniture
# 2     Office Supplies
# 3           Furniture
# 4     Office Supplies
# ...               ...
# 9989        Furniture
# 9990        Furniture
# 9991       Technology
# 9992  Office Supplies
# 9993  Office Supplies
#
# [9994 rows x 6 columns]

# %%
df.select_dtypes(exclude = "object")
# Out:
#      Order Date     Sales  Quantity  Discount    Profit
# 0    2016-11-08  261.9600         2      0.00   41.9136
# 1    2016-11-08  731.9400         3      0.00  219.5820
# 2    2016-06-12   14.6200         2      0.00    6.8714
# 3    2015-10-11  957.5775         5      0.45 -383.0310
# 4    2015-10-11   22.3680         2      0.20    2.5164
# ...         ...       ...       ...       ...       ...
# 9989 2014-01-21   25.2480         3      0.20    4.1028
# 9990 2017-02-26   91.9600         2      0.00   15.6332
# 9991 2017-02-26  258.5760         2      0.20   19.3932
# 9992 2017-02-26   29.6000         4      0.00   13.3200
# 9993 2017-05-04  243.1600         2      0.00   72.9480
#
# [9994 rows x 5 columns]

# %% [markdown]
# ### Query Function

# %%
df.head(2)
# Out:
#          Order ID Order Date Customer Name       City     State Region  \
# 0  CA-2016-152156 2016-11-08   Claire Gute  Henderson  Kentucky  South
# 1  CA-2016-152156 2016-11-08   Claire Gute  Henderson  Kentucky  South
#
#     Category   Sales  Quantity  Discount    Profit
# 0  Furniture  261.96         2       0.0   41.9136
# 1  Furniture  731.94         3       0.0  219.5820

# %%
df.query('Sales > 1000 & State == "Florida"')
# Out:
#             Order ID Order Date     Customer Name             City    State  \
# 990   CA-2015-153549 2015-03-29    Sara Luxemburg     Jacksonville  Florida
# 1046  CA-2016-169103 2016-03-08  Zuschuss Carroll            Miami  Florida
# 2697  CA-2014-145317 2014-03-18       Sean Miller     Jacksonville  Florida
# 3118  CA-2015-121720 2015-06-11           Jim Epp         Lakeland  Florida
# 3124  CA-2015-121720 2015-06-11           Jim Epp         Lakeland  Florida
# 3768  CA-2014-153913 2014-12-16         Ken Black          Hialeah  Florida
# 4297  CA-2017-129021 2017-08-23   Patrick O'Brill      Tallahassee  Florida
# 4519  CA-2017-107167 2017-06-10       Neil Ducich     Jacksonville  Florida
# 5185  CA-2015-134719 2015-10-10        John Dryer     Jacksonville  Florida
# 6048  CA-2015-105571 2015-11-07    Christine Phan            Miami  Florida
# 6988  CA-2017-158561 2017-11-11     Brenda Bowman  Fort Lauderdale  Florida
# 8236  CA-2017-102204 2017-05-01   Caroline Jumper     Jacksonville  Florida
# 9565  CA-2014-130428 2014-03-31      Trudy Glocke            Tampa  Florida
#
#      Region         Category      Sales  Quantity  Discount     Profit
# 990   South        Furniture   1166.920         5       0.2   131.2785
# 1046  South       Technology   1363.960         5       0.2    85.2475
# 2697  South       Technology  22638.480         6       0.5 -1811.0784
# 3118  South        Furniture   1123.920         5       0.2  -182.6370
# 3124  South  Office Supplies   1036.624         2       0.2    51.8312
# 3768  South        Furniture   1013.832         9       0.2   101.3832
# 4297  South       Technology   4367.896        13       0.2   327.5922
# 4519  South  Office Supplies   1347.520         8       0.2    84.2200
# 5185  South  Office Supplies   1801.632         6       0.2  -337.8060
# 6048  South  Office Supplies   1345.485         5       0.7 -1031.5385
# 6988  South  Office Supplies   1158.120         5       0.2   130.2885
# 8236  South        Furniture   2803.920         5       0.2     0.0000
# 9565  South        Furniture   1125.488         7       0.2    98.4802

# %% [markdown]
# ### Chaining Operations with pipe

# %%
salary = pd.read_excel("Superstore.xls", sheet_name="Salary")

# %%
salary
# Out:
#         Name  Salary_USD   Department
# 0      Ashok     60000.0           HR
# 1       Eric     70000.0  Engineering
# 2     Nature         NaN    Marketing
# 3      Virat     80000.0        Sport
# 4      Corey     65000.0           HR
# 5      Lucas     40000.0        Sales
# 6       Matt     55000.0  Engineering
# 7      Vivek     80000.0        GenAI
# 8  Abhisheak         NaN        GenAI

# %%
def convert_salary_to_eur(salary,conversion_rate=0.85):
    salary['Sales_EUR'] = salary["Salary_USD"] * conversion_rate
    return salary

def filter_by_salary(salary, min_salary):
    return salary[salary['Sales_EUR'] > min_salary]

def drop_na(salary):
    return salary.dropna()

# %%
salary_transformed = (salary
                      .pipe(drop_na) # first drop NaN values
                      .pipe(convert_salary_to_eur,conversion_rate = 0.90)
                      .pipe(filter_by_salary, min_salary = 50000)
                     )

# %%
salary
# Out:
#         Name  Salary_USD   Department
# 0      Ashok     60000.0           HR
# 1       Eric     70000.0  Engineering
# 2     Nature         NaN    Marketing
# 3      Virat     80000.0        Sport
# 4      Corey     65000.0           HR
# 5      Lucas     40000.0        Sales
# 6       Matt     55000.0  Engineering
# 7      Vivek     80000.0        GenAI
# 8  Abhisheak         NaN        GenAI

# %%
salary_transformed
# Out:
#     Name  Salary_USD   Department  Sales_EUR
# 0  Ashok     60000.0           HR    54000.0
# 1   Eric     70000.0  Engineering    63000.0
# 3  Virat     80000.0        Sport    72000.0
# 4  Corey     65000.0           HR    58500.0
# 7  Vivek     80000.0        GenAI    72000.0

# %% [markdown]
# ### Exploding a list-like column
#
# df.explode('column_with_lists')

# %%
data = {
    'Name' : ['Vivek', 'Ram', 'Abhishek'],
    'Projects' : [['HR','Marketing'],['Engineering','Data Science'],['Marketing']],
    'Salary_USD' : [60000,70000,80000]
}

# %%
data
# Out:
# {'Name': ['Vivek', 'Ram', 'Abhishek'],
#  'Projects': [['HR', 'Marketing'],
#   ['Engineering', 'Data Science'],
#   ['Marketing']],
#  'Salary_USD': [60000, 70000, 80000]}

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#        Name                     Projects  Salary_USD
# 0     Vivek              [HR, Marketing]       60000
# 1       Ram  [Engineering, Data Science]       70000
# 2  Abhishek                  [Marketing]       80000

# %%
df_exploded = data.explode('Projects')

# %%
df_exploded
# Out:
#        Name      Projects  Salary_USD
# 0     Vivek            HR       60000
# 0     Vivek     Marketing       60000
# 1       Ram   Engineering       70000
# 1       Ram  Data Science       70000
# 2  Abhishek     Marketing       80000

# %% [markdown]
# ### ApplyMap - Element wise Operations

# %%
salary.head()
# Out:
#      Name  Salary_USD   Department
# 0   Ashok     60000.0           HR
# 1    Eric     70000.0  Engineering
# 2  Nature         NaN    Marketing
# 3   Virat     80000.0        Sport
# 4   Corey     65000.0           HR

# %%
salary.applymap(lambda x : len(str(x)) if isinstance(x,str) else x)
# Out:
#    Name  Salary_USD  Department
# 0     5     60000.0           2
# 1     4     70000.0          11
# 2     6         NaN           9
# 3     5     80000.0           5
# 4     5     65000.0           2
# 5     5     40000.0           5
# 6     4     55000.0          11
# 7     5     80000.0           5
# 8     9         NaN           5

# %% [markdown]
# ### Creating new columns with pandas assign functions

# %%
df.head(1)
# Out:
#          Order ID Order Date Customer Name       City     State Region  \
# 0  CA-2016-152156 2016-11-08   Claire Gute  Henderson  Kentucky  South
#
#     Category   Sales  Quantity  Discount   Profit
# 0  Furniture  261.96         2       0.0  41.9136

# %%
df.assign(Total_Cost = lambda x : x['Sales'] * x['Quantity']).head()
# Out:
#          Order ID Order Date    Customer Name             City       State  \
# 0  CA-2016-152156 2016-11-08      Claire Gute        Henderson    Kentucky
# 1  CA-2016-152156 2016-11-08      Claire Gute        Henderson    Kentucky
# 2  CA-2016-138688 2016-06-12  Darrin Van Huff      Los Angeles  California
# 3  US-2015-108966 2015-10-11   Sean O'Donnell  Fort Lauderdale     Florida
# 4  US-2015-108966 2015-10-11   Sean O'Donnell  Fort Lauderdale     Florida
#
#   Region         Category     Sales  Quantity  Discount    Profit  Total_Cost
# 0  South        Furniture  261.9600         2      0.00   41.9136    523.9200
# 1  South        Furniture  731.9400         3      0.00  219.5820   2195.8200
# 2   West  Office Supplies   14.6200         2      0.00    6.8714     29.2400
# 3  South        Furniture  957.5775         5      0.45 -383.0310   4787.8875
# 4  South  Office Supplies   22.3680         2      0.20    2.5164     44.7360
