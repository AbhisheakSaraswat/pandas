# %%
import pandas as pd

# %%
df = pd.read_excel("Random Sales Data.xlsx")

# %%
df.head(1)
# Out:
#          Order ID Sales Representative  Location  City Region       Customer  \
# 0  NJ-2016-152156          Sara Snyder  New York  Troy   East  Raymond Young
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Bravo II Megaboss 12-Amp Hard Body Upright, Re...
#
#    Quantity  Price  Total Sale Amount
# 0         6  12.42              74.52

# %%
df.shape
# Out:
# (5684, 11)

# %%
# how to rename the column
df = df.rename(columns = {"Location":"State"})

# %%
df.rename(columns = {"Customer":"Customer Name","Quantity":"Pieces"}).head(2)
# Out:
#          Order ID Sales Representative       State       City Region  \
# 0  NJ-2016-152156          Sara Snyder    New York       Troy   East
# 1  NJ-2016-138688          Sara Snyder  New Jersey  Westfield   East
#
#    Customer Name           Order Date  \
# 0  Raymond Young  2016-01-01 00:00:00
# 1     Helen Dean  2016-01-01 00:00:00
#
#                                              Product  Pieces  Price  \
# 0  Bravo II Megaboss 12-Amp Hard Body Upright, Re...       6  12.42
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       7  12.42
#
#    Total Sale Amount
# 0              74.52
# 1              86.94

# %%
df.head(2)
# Out:
#          Order ID Sales Representative       State       City Region  \
# 0  NJ-2016-152156          Sara Snyder    New York       Troy   East
# 1  NJ-2016-138688          Sara Snyder  New Jersey  Westfield   East
#
#         Customer           Order Date  \
# 0  Raymond Young  2016-01-01 00:00:00
# 1     Helen Dean  2016-01-01 00:00:00
#
#                                              Product  Quantity  Price  \
# 0  Bravo II Megaboss 12-Amp Hard Body Upright, Re...         6  12.42
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         7  12.42
#
#    Total Sale Amount
# 0              74.52
# 1              86.94

# %%
df.rename(columns = {"Customer":"Customer Name","Quantity":"Pieces"},inplace = True)

# %%
df.head(2)
# Out:
#          Order ID Sales Representative       State       City Region  \
# 0  NJ-2016-152156          Sara Snyder    New York       Troy   East
# 1  NJ-2016-138688          Sara Snyder  New Jersey  Westfield   East
#
#    Customer Name           Order Date  \
# 0  Raymond Young  2016-01-01 00:00:00
# 1     Helen Dean  2016-01-01 00:00:00
#
#                                              Product  Pieces  Price  \
# 0  Bravo II Megaboss 12-Amp Hard Body Upright, Re...       6  12.42
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       7  12.42
#
#    Total Sale Amount
# 0              74.52
# 1              86.94

# %%
# delete a column

# %%
df.head(2)
# Out:
#          Order ID Sales Representative       State       City Region  \
# 0  NJ-2016-152156          Sara Snyder    New York       Troy   East
# 1  NJ-2016-138688          Sara Snyder  New Jersey  Westfield   East
#
#    Customer Name           Order Date  \
# 0  Raymond Young  2016-01-01 00:00:00
# 1     Helen Dean  2016-01-01 00:00:00
#
#                                              Product  Pieces  Price  \
# 0  Bravo II Megaboss 12-Amp Hard Body Upright, Re...       6  12.42
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       7  12.42
#
#    Total Sale Amount
# 0              74.52
# 1              86.94

# %%
df1 = df.drop(["State"],axis = 1) # 0 and 1 # axis = "columns"

# 0 : rows in data frame
# 1: columns in data frame

# %%
df1.head(2)
# Out:
#          Order ID Sales Representative       City Region  Customer Name  \
# 0  NJ-2016-152156          Sara Snyder       Troy   East  Raymond Young
# 1  NJ-2016-138688          Sara Snyder  Westfield   East     Helen Dean
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Bravo II Megaboss 12-Amp Hard Body Upright, Re...
# 1  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
#
#    Pieces  Price  Total Sale Amount
# 0       6  12.42              74.52
# 1       7  12.42              86.94

# %%
df.head(2)
# Out:
#          Order ID Sales Representative       State       City Region  \
# 0  NJ-2016-152156          Sara Snyder    New York       Troy   East
# 1  NJ-2016-138688          Sara Snyder  New Jersey  Westfield   East
#
#    Customer Name           Order Date  \
# 0  Raymond Young  2016-01-01 00:00:00
# 1     Helen Dean  2016-01-01 00:00:00
#
#                                              Product  Pieces  Price  \
# 0  Bravo II Megaboss 12-Amp Hard Body Upright, Re...       6  12.42
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       7  12.42
#
#    Total Sale Amount
# 0              74.52
# 1              86.94

# %%
df.drop(["State"], axis = "columns", inplace = True)
df.head(1)
# Out:
#          Order ID Sales Representative  City Region  Customer Name  \
# 0  NJ-2016-152156          Sara Snyder  Troy   East  Raymond Young
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Bravo II Megaboss 12-Amp Hard Body Upright, Re...
#
#    Pieces  Price  Total Sale Amount
# 0       6  12.42              74.52

# %%
df2 = df.drop(["Region","Pieces"], axis = 1)
df2.head()
# Out:
#          Order ID Sales Representative       City    Customer Name  \
# 0  NJ-2016-152156          Sara Snyder       Troy    Raymond Young
# 1  NJ-2016-138688          Sara Snyder  Westfield       Helen Dean
# 2  WA-2015-108966       Diane Gonzalez    Seattle   Shirley Chavez
# 3  NJ-2014-115812          Sara Snyder  Westfield       Brian Ryan
# 4  NJ-2017-114412          Sara Snyder  Westfield  Benjamin Willis
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Bravo II Megaboss 12-Amp Hard Body Upright, Re...
# 1  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  2016-01-01 00:00:00  Acme Hot Forged Carbon Steel Scissors with Nic...
# 3  2016-01-01 00:00:00      Bretford CR4500 Series Slim Rectangular Table
# 4  2016-01-01 00:00:00                     Eldon Fold 'N Roll Cart System
#
#    Price  Total Sale Amount
# 0  12.42              74.52
# 1  12.42              86.94
# 2  16.32              32.64
# ...

# %%
df2.index.values
# Out:
# array([   0,    1,    2, ..., 5681, 5682, 5683], dtype=int64)

# %%
df2.drop([0,2,4,6,8], axis = 0)
# Out:
#             Order ID Sales Representative       City       Customer Name  \
# 1     NJ-2016-138688          Sara Snyder  Westfield          Helen Dean
# 3     NJ-2014-115812          Sara Snyder  Westfield          Brian Ryan
# 5     WA-2016-161389       Patrick Graham    Seattle       Annie Jenkins
# 7     WA-2014-105893       Patrick Graham    Seattle       Annie Jenkins
# 9     NJ-2014-143336          Sara Snyder       Troy  Christopher Oliver
# ...              ...                  ...        ...                 ...
# 5679             NaN          Sara Snyder     Lowell       Andrew Howard
# 5680             NaN         Randy Watson     Lowell      Shirley Rivera
# 5681             NaN       Diane Gonzalez    Seattle       Ruby Gonzales
# 5682             NaN          Sara Snyder       Troy        Eric Stanley
# 5683             NaN       Patrick Graham    Seattle       Jerry Collins
#
#                Order Date                                            Product  \
# ...

# %%
df2.head()
# Out:
#          Order ID Sales Representative       City    Customer Name  \
# 0  NJ-2016-152156          Sara Snyder       Troy    Raymond Young
# 1  NJ-2016-138688          Sara Snyder  Westfield       Helen Dean
# 2  WA-2015-108966       Diane Gonzalez    Seattle   Shirley Chavez
# 3  NJ-2014-115812          Sara Snyder  Westfield       Brian Ryan
# 4  NJ-2017-114412          Sara Snyder  Westfield  Benjamin Willis
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Bravo II Megaboss 12-Amp Hard Body Upright, Re...
# 1  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  2016-01-01 00:00:00  Acme Hot Forged Carbon Steel Scissors with Nic...
# 3  2016-01-01 00:00:00      Bretford CR4500 Series Slim Rectangular Table
# 4  2016-01-01 00:00:00                     Eldon Fold 'N Roll Cart System
#
#    Price  Total Sale Amount
# 0  12.42              74.52
# 1  12.42              86.94
# 2  16.32              32.64
# ...

# %%
df2.drop([0,2,4,6,8], axis = 0, inplace = True)

# %%
df2.head()
# Out:
#          Order ID Sales Representative       City       Customer Name  \
# 1  NJ-2016-138688          Sara Snyder  Westfield          Helen Dean
# 3  NJ-2014-115812          Sara Snyder  Westfield          Brian Ryan
# 5  WA-2016-161389       Patrick Graham    Seattle       Annie Jenkins
# 7  WA-2014-105893       Patrick Graham    Seattle       Annie Jenkins
# 9  NJ-2014-143336          Sara Snyder       Troy  Christopher Oliver
#
#             Order Date                                            Product  \
# 1  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 3  2016-01-01 00:00:00      Bretford CR4500 Series Slim Rectangular Table
# 5  2016-01-01 00:00:00  Eldon Expressions Wood and Plastic Desk Access...
# 7  2016-01-01 00:00:00                     Mitel 5320 IP Phone VoIP phone
# 9  2016-01-02 00:00:00                   Belkin F5C206VTEL 6 Outlet Surge
#
#    Price  Total Sale Amount
# 1  12.42              86.94
# 3  12.42              12.42
# ...

# %%
df2.reset_index(inplace = True)

# %%
df2.head()
# Out:
#    index        Order ID Sales Representative       City       Customer Name  \
# 0      1  NJ-2016-138688          Sara Snyder  Westfield          Helen Dean
# 1      3  NJ-2014-115812          Sara Snyder  Westfield          Brian Ryan
# 2      5  WA-2016-161389       Patrick Graham    Seattle       Annie Jenkins
# 3      7  WA-2014-105893       Patrick Graham    Seattle       Annie Jenkins
# 4      9  NJ-2014-143336          Sara Snyder       Troy  Christopher Oliver
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 1  2016-01-01 00:00:00      Bretford CR4500 Series Slim Rectangular Table
# 2  2016-01-01 00:00:00  Eldon Expressions Wood and Plastic Desk Access...
# 3  2016-01-01 00:00:00                     Mitel 5320 IP Phone VoIP phone
# 4  2016-01-02 00:00:00                   Belkin F5C206VTEL 6 Outlet Surge
#
#    Price  Total Sale Amount
# 0  12.42              86.94
# ...

# %%
df2.drop(['index'], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#          Order ID Sales Representative       City       Customer Name  \
# 0  NJ-2016-138688          Sara Snyder  Westfield          Helen Dean
# 1  NJ-2014-115812          Sara Snyder  Westfield          Brian Ryan
# 2  WA-2016-161389       Patrick Graham    Seattle       Annie Jenkins
# 3  WA-2014-105893       Patrick Graham    Seattle       Annie Jenkins
# 4  NJ-2014-143336          Sara Snyder       Troy  Christopher Oliver
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 1  2016-01-01 00:00:00      Bretford CR4500 Series Slim Rectangular Table
# 2  2016-01-01 00:00:00  Eldon Expressions Wood and Plastic Desk Access...
# 3  2016-01-01 00:00:00                     Mitel 5320 IP Phone VoIP phone
# 4  2016-01-02 00:00:00                   Belkin F5C206VTEL 6 Outlet Surge
#
#    Price  Total Sale Amount
# 0  12.42              86.94
# 1  12.42              12.42
# ...

# %%
df2.set_index("Customer Name", inplace = True)

# %%
df2.head()
# Out:
#                           Order ID Sales Representative       City  \
# Customer Name
# Helen Dean          NJ-2016-138688          Sara Snyder  Westfield
# Brian Ryan          NJ-2014-115812          Sara Snyder  Westfield
# Annie Jenkins       WA-2016-161389       Patrick Graham    Seattle
# Annie Jenkins       WA-2014-105893       Patrick Graham    Seattle
# Christopher Oliver  NJ-2014-143336          Sara Snyder       Troy
#
#                              Order Date  \
# Customer Name
# Helen Dean          2016-01-01 00:00:00
# Brian Ryan          2016-01-01 00:00:00
# Annie Jenkins       2016-01-01 00:00:00
# Annie Jenkins       2016-01-01 00:00:00
# Christopher Oliver  2016-01-02 00:00:00
#
#                                                               Product  Price  \
# Customer Name
# Helen Dean          Hon Deluxe Fabric Upholstered Stacking Chairs,...  12.42
# Brian Ryan              Bretford CR4500 Series Slim Rectangular Table  12.42
# ...

# %%
df2.index.get_loc("Brian Ryan")
# Out:
# array([False,  True, False, ..., False, False, False])

# %%
df2[df2.index.get_loc("Brian Ryan")]
# Out:
#                      Order ID Sales Representative       City  \
# Customer Name
# Brian Ryan     NJ-2014-115812          Sara Snyder  Westfield
# Brian Ryan     NJ-2014-124429       Frances Warren  Westfield
# Brian Ryan     NJ-2016-108504       Frances Warren  Westfield
# Brian Ryan     NJ-2017-109946         Randy Watson  Westfield
# Brian Ryan     NJ-2016-149902          Sara Snyder  Westfield
# Brian Ryan     NJ-2017-115175          Sara Snyder  Westfield
# Brian Ryan     NJ-2015-129042          Sara Snyder  Westfield
# Brian Ryan     NJ-2017-163006         Randy Watson  Westfield
# Brian Ryan     NJ-2016-103107          Sara Snyder  Westfield
# Brian Ryan     NJ-2017-120147         Randy Watson  Westfield
# Brian Ryan     NJ-2015-132136          Sara Snyder  Westfield
# Brian Ryan     NJ-2014-157847          Sara Snyder  Westfield
# Brian Ryan     NJ-2017-110149         Randy Watson  Westfield
# Brian Ryan     NJ-2016-123610          Sara Snyder  Westfield
# ...

# %%
df2.reset_index(inplace = True)

# %%
df2.head()
# Out:
#         Customer Name        Order ID Sales Representative       City  \
# 0          Helen Dean  NJ-2016-138688          Sara Snyder  Westfield
# 1          Brian Ryan  NJ-2014-115812          Sara Snyder  Westfield
# 2       Annie Jenkins  WA-2016-161389       Patrick Graham    Seattle
# 3       Annie Jenkins  WA-2014-105893       Patrick Graham    Seattle
# 4  Christopher Oliver  NJ-2014-143336          Sara Snyder       Troy
#
#             Order Date                                            Product  \
# 0  2016-01-01 00:00:00  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 1  2016-01-01 00:00:00      Bretford CR4500 Series Slim Rectangular Table
# 2  2016-01-01 00:00:00  Eldon Expressions Wood and Plastic Desk Access...
# 3  2016-01-01 00:00:00                     Mitel 5320 IP Phone VoIP phone
# 4  2016-01-02 00:00:00                   Belkin F5C206VTEL 6 Outlet Surge
#
#    Price  Total Sale Amount
# 0  12.42              86.94
# 1  12.42              12.42
# ...

# %%
df2.set_index(["City","Sales Representative"], inplace = True)

# %%
df2.head()
# Out:
#                                      Customer Name        Order ID  \
# City      Sales Representative
# Westfield Sara Snyder                   Helen Dean  NJ-2016-138688
#           Sara Snyder                   Brian Ryan  NJ-2014-115812
# Seattle   Patrick Graham             Annie Jenkins  WA-2016-161389
#           Patrick Graham             Annie Jenkins  WA-2014-105893
# Troy      Sara Snyder           Christopher Oliver  NJ-2014-143336
#
#                                          Order Date  \
# City      Sales Representative
# Westfield Sara Snyder           2016-01-01 00:00:00
#           Sara Snyder           2016-01-01 00:00:00
# Seattle   Patrick Graham        2016-01-01 00:00:00
#           Patrick Graham        2016-01-01 00:00:00
# Troy      Sara Snyder           2016-01-02 00:00:00
#
#                                                                           Product  \
# City      Sales Representative
# ...
